# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('/Salary_Data.csv')

x = data['YearsExperience']
y = data['Salary']

N = len(x)

sum_x = x.sum()
sum_y = y.sum()
sum_xy = (x * y).sum()
sum_x_squared = (x ** 2).sum()

m = (N * sum_xy - sum_x * sum_y) / (N * sum_x_squared - sum_x ** 2)
c = (sum_y - m * sum_x) / N

y_pred = m * x + c

plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='blue', label='Data points')
plt.plot(x, y_pred, color='red', label='Best fit line')
plt.title('Years of Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid(True)
plt.legend()
plt.show()

print(f"Slope (Coefficient): {m}")
print(f"Intercept: {c}")
# Out:
# Slope (Coefficient): 9449.962321455077
# Intercept: 25792.200198668685

# %%
def calculate_errors(x_test, y_test, m, c):
    y_pred = m * x_test + c

    mse = np.mean((y_test - y_pred) ** 2)

    mae = np.mean(np.abs(y_test - y_pred))

    return mse, mae

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)
mse,mae = calculate_errors(X_test, y_test, m, c)
print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# Mean Squared Error (MSE): 10909090.287102837
# Mean Absolute Error (MAE): 2304.2056011630907

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.75, random_state=0)
mse,mae = calculate_errors(X_test, y_test, m, c)
print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# Mean Squared Error (MSE): 35056133.19452496
# Mean Absolute Error (MAE): 4868.521717287802

# %%
data = {
    'x1': [1.2,2.4,3.5,4.1,1.9,3.7,2.1,3.3,2.8,4],
    'x2': [2.3,1.9,2.7,3,2.8,2.5,3.2,2.4,3.1,3.3],
    'x3': [3.1,2.8,1.5,3.6,2.5,1.9,2.2,3,1.8,2.7],
    'x4': [4.2,3.5,2.9,4.8,3.2,4,4.1,4.5,3.6,4.9],
    'y': [15.6,13.1,12.4,18.2,14.1,16,14.5,17.3,14.9,19.2]
}
df = pd.DataFrame(data)
df.to_csv('data.csv', index=False)

# %%
data1 = {
    'x1': [1.2,2.4,3.5,4.1,1.9,3.7,2.1,3.3,2.8,4],
    'y': [15.6,13.1,12.4,18.2,14.1,16,14.5,17.3,14.9,19.2]
}
df = pd.DataFrame(data1)
df.to_csv('data1.csv', index=False)

# %%
data2 = {
    'x2': [2.3,1.9,2.7,3,2.8,2.5,3.2,2.4,3.1,3.3],
    'y': [15.6,13.1,12.4,18.2,14.1,16,14.5,17.3,14.9,19.2]
}
df = pd.DataFrame(data2)
df.to_csv('data2.csv', index=False)

# %%
data3 = {
    'x3': [3.1,2.8,1.5,3.6,2.5,1.9,2.2,3,1.8,2.7],
    'y': [15.6,13.1,12.4,18.2,14.1,16,14.5,17.3,14.9,19.2]
}
df = pd.DataFrame(data3)
df.to_csv('data3.csv', index=False)

# %%
data4 = {
    'x4': [4.2,3.5,2.9,4.8,3.2,4,4.1,4.5,3.6,4.9],
    'y': [15.6,13.1,12.4,18.2,14.1,16,14.5,17.3,14.9,19.2]
}
df = pd.DataFrame(data4)
df.to_csv('data4.csv', index=False)

# %%
d =  pd.read_csv('/content/data.csv')
d1 = pd.read_csv('/content/data1.csv')
d2 = pd.read_csv('/content/data2.csv')
d3 = pd.read_csv('/content/data3.csv')
d4 = pd.read_csv('/content/data4.csv')

# %%
plt.figure(figsize=(10, 6))
x1 = d1['x1']
y = d['y']
x2 = d2['x2']
x3 = d3['x3']
x4 = d4['x4']
plt.scatter(d1['x1'], d['y'])
plt.scatter(d2['x2'], d2['y'])
plt.scatter(d3['x3'], d3['y'])
plt.scatter(d4['x4'], d4['y'])
